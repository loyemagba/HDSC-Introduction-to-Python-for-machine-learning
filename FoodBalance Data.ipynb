# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt 
# %matplotlib inline
import warnings
warnings.filterwarnings('ignore')

# %%
df = pd.read_csv("C:/Users/loye/Desktop/FoodBalanceSheets_E_Africa_NOFLAG.csv", encoding = "latin1")

# %%
df.head()
# Out:
#    Area Code     Area  Item Code         Item  Element Code  \
# 0          4  Algeria       2501   Population           511
# 1          4  Algeria       2501   Population          5301
# 2          4  Algeria       2901  Grand Total           664
# 3          4  Algeria       2901  Grand Total           674
# 4          4  Algeria       2901  Grand Total           684
#
#                                   Element             Unit     Y2014  \
# 0           Total Population - Both sexes     1000 persons  38924.00
# 1                Domestic supply quantity      1000 tonnes      0.00
# 2           Food supply (kcal/capita/day)  kcal/capita/day   3377.00
# 3  Protein supply quantity (g/capita/day)     g/capita/day     94.90
# 4      Fat supply quantity (g/capita/day)     g/capita/day     80.06
#
#       Y2015     Y2016     Y2017     Y2018
# 0  39728.00  40551.00  41389.00  42228.00
# 1      0.00      0.00      0.00      0.00
# 2   3379.00   3372.00   3341.00   3322.00
# ...

# %%
df.shape
# Out:
# (60943, 12)

# %%
df.describe(include = 'all')
# Out:
#            Area Code   Area     Item Code                     Item  \
# count   60943.000000  60943  60943.000000                    60943
# unique           NaN     49           NaN                      119
# top              NaN  Kenya           NaN  Milk - Excluding Butter
# freq             NaN   1560           NaN                     1262
# mean      134.265576    NaN   2687.176706                      NaN
# std        72.605709    NaN    146.055739                      NaN
# min         4.000000    NaN   2501.000000                      NaN
# 25%        74.000000    NaN   2562.000000                      NaN
# 50%       136.000000    NaN   2630.000000                      NaN
# 75%       195.000000    NaN   2775.000000                      NaN
# max       276.000000    NaN   2961.000000                      NaN
#
#         Element Code                   Element         Unit          Y2014  \
# count   60943.000000                     60943        60943   59354.000000
# ...

# %%
df.dtypes
# Out:
# Area Code         int64
# Area             object
# Item Code         int64
# Item             object
# Element Code      int64
# Element          object
# Unit             object
# Y2014           float64
# Y2015           float64
# Y2016           float64
# Y2017           float64
# Y2018           float64
# dtype: object

# %% [markdown]
# #### Checking for missing columns

# %%
for column in df.isnull().columns.values.tolist():
    print(column)
    print (df.isnull()[column].value_counts())
    print("")
# Out:
# Area Code
# False    60943
# Name: Area Code, dtype: int64
#
# Area
# False    60943
# Name: Area, dtype: int64
#
# Item Code
# False    60943
# Name: Item Code, dtype: int64
#
# Item
# False    60943
# Name: Item, dtype: int64
#
# Element Code
# False    60943
# Name: Element Code, dtype: int64
#
# Element
# False    60943
# Name: Element, dtype: int64
#
# Unit
# False    60943
# Name: Unit, dtype: int64
#
# Y2014
# False    59354
# True      1589
# Name: Y2014, dtype: int64
#
# Y2015
# False    59395
# True      1548
# Name: Y2015, dtype: int64
#
# Y2016
# False    59408
# True      1535
# Name: Y2016, dtype: int64
#
# Y2017
# False    59437
# True      1506
# Name: Y2017, dtype: int64
#
# Y2018
# False    59507
# True      1436
# Name: Y2018, dtype: int64

# %% [markdown]
# ## Question 11

# %%
df_item = df.groupby(['Item']).sum()
df_item.loc['Animal fats']
# Out:
# Area Code         85279.00
# Item Code       1882494.00
# Element Code    2567303.00
# Y2014            209460.54
# Y2015            200675.72
# Y2016            183314.22
# Y2017            269617.53
# Y2018            269648.27
# Name: Animal fats, dtype: float64

# %% [markdown]
# ## Question 12

# %%
df_mean = df[['Y2015']].mean().round(3)
print('The mean value for',df_mean)
# Out:
# The mean value for Y2015    135.236
# dtype: float64

# %%
df_std = df[['Y2015']].std().round(3)
print('The standard deviation value for',df_std)
# Out:
# The standard deviation value for Y2015    1603.404
# dtype: float64

# %% [markdown]
# ## Question 13

# %%
print('The number of missing values for',df[['Y2016']].isnull().sum())
# Out:
# The number of missing values for Y2016    1535
# dtype: int64

# %%
percentage_missing = df[['Y2016']].isnull().sum()*100/len(df[['Y2016']])

# %%
# rounding percentage of missing values to 2 decimal places
percentage_round = round(percentage_missing, 2)
percentage_round
# Out:
# Y2016    2.52
# dtype: float64

# %% [markdown]
# ## Question 14

# %%
df.corr()
# Out:
#               Area Code  Item Code  Element Code     Y2014     Y2015  \
# Area Code      1.000000  -0.005159     -0.000209  0.006164  0.005472
# Item Code     -0.005159   1.000000     -0.024683  0.021722  0.020857
# Element Code  -0.000209  -0.024683      1.000000  0.024457  0.023889
# Y2014          0.006164   0.021722      0.024457  1.000000  0.994647
# Y2015          0.005472   0.020857      0.023889  0.994647  1.000000
# Y2016          0.005247   0.020109      0.023444  0.996081  0.995739
# Y2017          0.005006   0.021494      0.024254  0.995230  0.988048
# Y2018          0.005665   0.021314      0.024279  0.994872  0.988208
#
#                  Y2016     Y2017     Y2018
# Area Code     0.005247  0.005006  0.005665
# Item Code     0.020109  0.021494  0.021314
# Element Code  0.023444  0.024254  0.024279
# Y2014         0.996081  0.995230  0.994872
# Y2015         0.995739  0.988048  0.988208
# Y2016         1.000000  0.992785  0.992757
# ...

# %% [markdown]
# #### The year 2014 had the highest correlation value with Element Code with a value of 0.024457

# %% [markdown]
# ## Question 15

# %%
df_element = df.groupby(['Element']).sum()
df_element.loc['Import Quantity']
# Out:
# Area Code         688174.00
# Item Code       13795966.00
# Element Code    28834929.00
# Y2014             274144.48
# Y2015             267018.46
# Y2016             286582.78
# Y2017             294559.09
# Y2018             287997.09
# Name: Import Quantity, dtype: float64

# %% [markdown]
# #### The year 2017 had the highest sum for Import Quantity

# %% [markdown]
# ## Question 16

# %%
df_element.loc['Production']
# Out:
# Area Code         526751.00
# Item Code       10450053.00
# Element Code    21388191.00
# Y2014            1931287.75
# Y2015            1947019.39
# Y2016            1943537.15
# Y2017            2030056.89
# Y2018            2075072.89
# Name: Production, dtype: float64

# %% [markdown]
# #### The year 2014 had a total sum of 1931287.75

# %% [markdown]
# ## Question 17

# %%
df_element['Y2018']
# Out:
# Element
# Domestic supply quantity                  2161192.10
# Export Quantity                            181594.80
# Fat supply quantity (g/capita/day)          10258.69
# Feed                                       233489.68
# Food                                      1303841.28
# Food supply (kcal/capita/day)              455261.00
# Food supply quantity (kg/capita/yr)         49056.85
# Import Quantity                            287997.09
# Losses                                     163902.00
# Other uses (non-food)                       91300.97
# Processing                                 308429.00
# Production                                2075072.89
# Protein supply quantity (g/capita/day)      11833.56
# Residuals                                   34864.00
# Seed                                        25263.14
# Stock Variation                             20577.91
# Total Population - Both sexes             1140605.00
# Tourist consumption                            90.00
# ...

# %% [markdown]
# #### Domestic supply quantity had the highest sum in 2018

# %% [markdown]
# ## Question 18

# %% [markdown]
# #### Protein supply quantity (g/capita/day) had the third lowest figure

# %% [markdown]
# ## Question 19

# %%
df_area = df.groupby(['Area', 'Element']).sum()
df_area
# Out:
#                                                  Area Code  Item Code  \
# Area     Element
# Algeria  Domestic supply quantity                      464     311204
#          Export Quantity                               392     264011
#          Fat supply quantity (g/capita/day)            432     291489
#          Feed                                           88      58967
#          Food                                          420     282744
# ...                                                    ...        ...
# Zimbabwe Protein supply quantity (g/capita/day)      20453     304589
#          Residuals                                   18824     277476
#          Seed                                         3439      50560
#          Stock Variation                             17195     254157
#          Total Population - Both sexes                 181       2501
#
#                                                  Element Code     Y2014  \
# Area     Element
# ...

# %%
df_area.loc['Algeria']
# Out:
#                                         Area Code  Item Code  Element Code  \
# Element
# Domestic supply quantity                      464     311204        614916
# Export Quantity                               392     264011        579278
# Fat supply quantity (g/capita/day)            432     291489         73872
# Feed                                           88      58967        121462
# Food                                          420     282744        539910
# Food supply (kcal/capita/day)                 432     291489         71712
# Food supply quantity (kg/capita/yr)           420     282744         67725
# Import Quantity                               448     301030        628432
# Losses                                        208     139857        266396
# Other uses (non-food)                         148     101269        190698
# Processing                                    140      93537        179585
# ...

# %% [markdown]
# #### The total for import quantity for Algeria in 2018 is 36238.29

# %% [markdown]
# ## Question 20

# %%
df[['Area']].nunique()
# Out:
# Area    49
# dtype: int64

# %% [markdown]
# #### The total number of unique countries is 49
